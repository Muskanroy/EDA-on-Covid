# %% [markdown]
# ## Importing libraries

# %%
# Pandas - Data manipulation and analysis library
import pandas as pd
#NumPy - mathematical functions on multi-dimensional arrays and matrices
import numpy as np
#Matplotlib - plotting library to create graphs and charts
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Let's load the csv file containing data of confirmed cases,active cases,cured,and death in India and its states

# %%
data1 = pd.read_csv("C:\\Users\\muska\\Downloads\COVID.csv")

# %%
data1
# Out:
#        S. No.        Date Region  Confirmed Cases  Active Cases  \
# 0           1  12-03-2020  India               74          71.0
# 1           2  13-03-2020  India               75          71.0
# 2           3  14-03-2020  India               84          72.0
# 3           4  15-03-2020  India              107          95.0
# 4           5  16-03-2020  India              114          99.0
# ...       ...         ...    ...              ...           ...
# 14434   14435  12-04-2021  World        135723906           NaN
# 14435   14436  13-04-2021  World        136291755           NaN
# 14436   14437  14-04-2021  World        137064708           NaN
# 14437   14438  15-04-2021  World        137883576           NaN
# 14438   14439  16-04-2021  World        138688383           NaN
#
#        Cured/Discharged      Death
# 0                   3.0        0.0
# 1                   3.0        1.0
# 2                  10.0        2.0
# 3                  10.0        2.0
# ...

# %% [markdown]
# getting data for India showing confirmed cases,active cases,cured and death

# %%
data2=data1.loc[data1['Region']=='India']
data2
# Out:
#      S. No.        Date Region  Confirmed Cases  Active Cases  \
# 0         1  12-03-2020  India               74          71.0
# 1         2  13-03-2020  India               75          71.0
# 2         3  14-03-2020  India               84          72.0
# 3         4  15-03-2020  India              107          95.0
# 4         5  16-03-2020  India              114          99.0
# ..      ...         ...    ...              ...           ...
# 388     389  12-04-2021  India         13527717     1201009.0
# 389     390  13-04-2021  India         13689453     1264698.0
# 390     391  14-04-2021  India         13873825     1365704.0
# 391     392  15-04-2021  India         14074564     1471877.0
# 392     393  16-04-2021  India         14291917     1569743.0
#
#      Cured/Discharged     Death
# 0                 3.0       0.0
# 1                 3.0       1.0
# 2                10.0       2.0
# 3                10.0       2.0
# 4                13.0       2.0
# ...

# %% [markdown]
# getting active cases in India

# %%
active= data2['Active Cases']

# %%
active
# Out:
# 0           71.0
# 1           71.0
# 2           72.0
# 3           95.0
# 4           99.0
#          ...
# 388    1201009.0
# 389    1264698.0
# 390    1365704.0
# 391    1471877.0
# 392    1569743.0
# Name: Active Cases, Length: 393, dtype: float64

# %% [markdown]
# Getting Cured data in India

# %%
cured = data2['Cured/Discharged']

# %%
cured
# Out:
# 0             3.0
# 1             3.0
# 2            10.0
# 3            10.0
# 4            13.0
#           ...
# 388    12156529.0
# 389    12253697.0
# 390    12336036.0
# 391    12429564.0
# 392    12547866.0
# Name: Cured/Discharged, Length: 393, dtype: float64

# %%
death = data2['Death']

# %%
death
# Out:
# 0           0.0
# 1           1.0
# 2           2.0
# 3           2.0
# 4           2.0
#          ...
# 388    170179.0
# 389    171058.0
# 390    172085.0
# 391    173123.0
# 392    174308.0
# Name: Death, Length: 393, dtype: float64

# %%
date = data2['Date']

# %%
date
# Out:
# 0      12-03-2020
# 1      13-03-2020
# 2      14-03-2020
# 3      15-03-2020
# 4      16-03-2020
#           ...
# 388    12-04-2021
# 389    13-04-2021
# 390    14-04-2021
# 391    15-04-2021
# 392    16-04-2021
# Name: Date, Length: 393, dtype: object

# %% [markdown]
# The plot below shows the daywise confirmed cases,active cases,cured and death in India

# %%
plt.figure(figsize=(16,8),dpi=400)
plt.plot(data2.Date,data2['Confirmed Cases'],'g.-',label = 'Confirmed')
plt.plot(data2.Date,data2['Active Cases'],'r.-',label='Active')
plt.plot(data2.Date,data2['Cured/Discharged'],'b.-',label='Cured/Discharged')
plt.plot(data2.Date,data2['Death'],'y.-',label='Death')
plt.ylabel("No of Cases",fontdict={'fontweight':'bold','fontsize':18})           
plt.title("Day Wise Cases:India",fontdict={'fontweight':'bold','fontsize':22})
plt.xticks(data2.Date[:393:8])
plt.xticks(rotation = 90)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Getting data for 5 most affected states

# %%
#getting data for Maharashtra
data3=data1.loc[data1['Region']=='Maharashtra']

# %%
data3
# Out:
#       S. No.        Date       Region  Confirmed Cases  Active Cases  \
# 7911    7912  12-03-2020  Maharashtra               11          11.0
# 7912    7913  13-03-2020  Maharashtra               11          11.0
# 7913    7914  14-03-2020  Maharashtra               14          14.0
# 7914    7915  15-03-2020  Maharashtra               31          31.0
# 7915    7916  16-03-2020  Maharashtra               32          32.0
# ...      ...         ...          ...              ...           ...
# 8299    8300  12-04-2021  Maharashtra          3407245      567097.0
# 8300    8301  13-04-2021  Maharashtra          3458996      566278.0
# 8301    8302  14-04-2021  Maharashtra          3519208      594585.0
# 8302    8303  15-04-2021  Maharashtra          3578160      613635.0
# 8303    8304  16-04-2021  Maharashtra          3639855      621646.0
#
#       Cured/Discharged    Death
# 7911               0.0      0.0
# 7912               0.0      0.0
# 7913               0.0      0.0
# ...

# %%
#getting data for Kerala
data4 =data1.loc[data1['Region']=='Kerala']

# %%
data4
# Out:
#       S. No.        Date  Region  Confirmed Cases  Active Cases  \
# 6488    6489  12-03-2020  Kerala               17          14.0
# 6489    6490  13-03-2020  Kerala               17          14.0
# 6490    6491  14-03-2020  Kerala               19          16.0
# 6491    6492  15-03-2020  Kerala               22          19.0
# 6492    6493  16-03-2020  Kerala               23          20.0
# ...      ...         ...     ...              ...           ...
# 6876    6877  12-04-2021  Kerala          1167190       44707.0
# 6877    6878  13-04-2021  Kerala          1172882       47914.0
# 6878    6879  14-04-2021  Kerala          1180397       52450.0
# 6879    6880  15-04-2021  Kerala          1189175       58564.0
# 6880    6881  16-04-2021  Kerala          1197301       63970.0
#
#       Cured/Discharged   Death
# 6488               3.0     0.0
# 6489               3.0     0.0
# 6490               3.0     0.0
# 6491               3.0     0.0
# 6492               3.0     0.0
# ...

# %%
#getting data for Karnataka only 
data5=data1.loc[data1['Region']=='Karnataka']

# %%
data5
# Out:
#       S. No.        Date     Region  Confirmed Cases  Active Cases  \
# 6095    6096  12-03-2020  Karnataka                4           4.0
# 6096    6097  13-03-2020  Karnataka                5           4.0
# 6097    6098  14-03-2020  Karnataka                6           5.0
# 6098    6099  15-03-2020  Karnataka                6           5.0
# 6099    6100  16-03-2020  Karnataka                6           5.0
# ...      ...         ...        ...              ...           ...
# 6483    6484  12-04-2021  Karnataka          1065290       69244.0
# 6484    6485  13-04-2021  Karnataka          1074869       76004.0
# 6485    6486  14-04-2021  Karnataka          1083647       78636.0
# 6486    6487  15-04-2021  Karnataka          1094912       85499.0
# 6487    6488  16-04-2021  Karnataka          1109650       96580.0
#
#       Cured/Discharged    Death
# 6095               0.0      0.0
# 6096               0.0      1.0
# 6097               0.0      1.0
# ...

# %%
#getting data dor Tamil Nadu
data6 =data1.loc[data1['Region']=='Tamil Nadu']

# %%
data6
# Out:
#        S. No.        Date      Region  Confirmed Cases  Active Cases  \
# 11717   11718  12-03-2020  Tamil Nadu                1           1.0
# 11718   11719  13-03-2020  Tamil Nadu                1           1.0
# 11719   11720  14-03-2020  Tamil Nadu                1           1.0
# 11720   11721  15-03-2020  Tamil Nadu                1           1.0
# 11721   11722  16-03-2020  Tamil Nadu                1           1.0
# ...       ...         ...         ...              ...           ...
# 12105   12106  12-04-2021  Tamil Nadu           933434       41955.0
# 12106   12107  13-04-2021  Tamil Nadu           940145       46308.0
# 12107   12108  14-04-2021  Tamil Nadu           947129       49985.0
# 12108   12109  15-04-2021  Tamil Nadu           954948       54315.0
# 12109   12110  16-04-2021  Tamil Nadu           962935       58097.0
#
#        Cured/Discharged    Death
# 11717               0.0      0.0
# 11718               0.0      0.0
# 11719               0.0      0.0
# ...

# %%
#getting data for Andhra Pradesh
data7=data1.loc[data1['Region']=='Andhra Pradesh']

# %%
data7
# Out:
#       S. No.        Date          Region  Confirmed Cases  Active Cases  \
# 771      772  12-03-2020  Andhra Pradesh                1           1.0
# 772      773  13-03-2020  Andhra Pradesh                1           1.0
# 773      774  14-03-2020  Andhra Pradesh                1           1.0
# 774      775  15-03-2020  Andhra Pradesh                1           1.0
# 775      776  16-03-2020  Andhra Pradesh                1           1.0
# ...      ...         ...             ...              ...           ...
# 1159    1160  12-04-2021  Andhra Pradesh           925401       20954.0
# 1160    1161  13-04-2021  Andhra Pradesh           928664       23115.0
# 1161    1162  14-04-2021  Andhra Pradesh           932892       25850.0
# 1162    1163  15-04-2021  Andhra Pradesh           937049       28383.0
# 1163    1164  16-04-2021  Andhra Pradesh           942135       31710.0
#
#       Cured/Discharged   Death
# 771                0.0     0.0
# 772                0.0     0.0
# ...

# %% [markdown]
# The plot below shows the daywise confirmed cases in India and 5 Most Affected States

# %%
plt.figure(figsize=(16,8),dpi=400)
plt.plot(data2.Date,data2['Confirmed Cases'],'g.-',label = 'India')
plt.plot(data3.Date,data3['Confirmed Cases'],'r.-',label='Maharashtra')
plt.plot(data4.Date,data4['Confirmed Cases'],'b.-',label='Kerala')
plt.plot(data5.Date,data5['Confirmed Cases'],'y.-',label='Karnataka')
plt.plot(data6.Date,data6['Confirmed Cases'],'m.-',label='Tamil Nadu')
plt.plot(data7.Date,data7['Confirmed Cases'],'c.-',label='Andhra Pradesh')
plt.ylabel("No of Confirmed Cases",fontdict={'fontweight':'bold','fontsize':18})           
plt.title("Day Wise cases in 5 Most Affected states",fontdict={'fontweight':'bold','fontsize':22})
plt.xticks(data3.Date[:393:8])
plt.xticks(rotation = 90)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# The plot below shows the daywise death in India and 5 most affected states

# %%
plt.figure(figsize=(22,12),dpi=300)
plt.plot(data2.Date,data2['Death'],'g.-',label = 'India')
plt.plot(data3.Date,data3['Death'],'r.-',label='Maharashtra')
plt.plot(data4.Date,data4['Death'],'b.-',label='Kerala')
plt.plot(data5.Date,data5['Death'],'y.-',label='Karnataka')
plt.plot(data6.Date,data6['Death'],'c.-',label='Tamil Nadu')
plt.plot(data7.Date,data7['Death'],'m.-',label='Andhra Pradesh')
plt.ylabel("No of Death",fontdict={'fontweight':'bold','fontsize':20})           
plt.title("Day Wise Death in 5 Most Affected states",fontdict={'fontweight':'bold','fontsize':22})
plt.xticks(data3.Date[:393:5])
plt.xticks(rotation = 90)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# The plot below shows the daywise confirmed and active cases in 5 most affected states

# %%
fig,(ax1,ax2)=plt.subplots(nrows=2,ncols=1,sharex=True)
#ax1.set_figure(figsize=(16,8),dpi=400)
#ax2.figure(figsize=(16,8),dpi=400)
#ax1.plot(data2.Date,data2['Confirmed Cases'],'k.-',label = 'India')
ax1.plot(data3.Date,data3['Confirmed Cases'],'r.-',label='Maharashtra')
ax1.plot(data4.Date,data4['Confirmed Cases'],'b.-',label='Kerala')
ax1.plot(data5.Date,data5['Confirmed Cases'],'y.-',label='Karnataka')
ax1.plot(data6.Date,data6['Confirmed Cases'],'g.-',label='Tamil Nadu')
ax1.plot(data7.Date,data7['Confirmed Cases'],'m.-',label='Andhra Pradesh')
ax1.set_ylabel("No of Confirmed Cases",fontdict={'fontweight':'bold','fontsize':20})           
ax1.set_title("Day Wise cases in 5 Most Affected states",fontdict={'fontweight':'bold','fontsize':25})
ax1.grid()
ax1.legend()

#ax2.plot(data2.Date,data2['Active Cases'],'k.-',label = 'India')
ax2.plot(data3.Date,data3['Active Cases'],'r.-',label='Maharashtra')
ax2.plot(data4.Date,data4['Active Cases'],'b.-',label='Kerala')
ax2.plot(data5.Date,data5['Active Cases'],'y.-',label='Karnataka')
ax2.plot(data6.Date,data6['Active Cases'],'g.-',label='Tamil Nadu')
ax2.plot(data7.Date,data7['Active Cases'],'c.-',label='Andhra Pradesh')
ax2.set_ylabel("No of Active Cases",fontdict={'fontweight':'bold','fontsize':20})
ax2.set_xticks(data3.Date[:393:8])
for tick in ax2.get_xticklabels():
        tick.set_rotation(90)
fig.set_figheight(16)
fig.set_figwidth(20)    
ax2.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Relation in vaccinated,confirmed,active,death cases in 5 most affected states
# The stacked bar plot below shows the relation in vaccinated,confirmed,active and death cases in 5 most affected states

# %%
plt.figure(figsize=(16,8),dpi=300)
x=['Maharashtra','Kerala','Karnataka','Tamil Nadu','Andhra Pradesh']
Vaccinated=[ 12945000,6243833,7768994,4892488,4927736]
Confirmed=[3839338,1239424,1161065,991451,962037]
Active = [672037,94009,133562,70391,44686]
Death=[60473,4929,13351,13113,7410]
plt.bar(x,Vaccinated,0.4,label="Vaccinated")
plt.bar(x,Confirmed,0.4,label="Confirmed")
plt.bar(x,Active,0.4,label="Active")
plt.bar(x,Death,0.4,label="Death")
plt.title("Relation in vaccinated,confirmed,active,death cases in 5 most affected states",fontdict={'fontweight':'bold','fontsize':18})
plt.ylabel('No of people',fontdict={'fontweight':'bold','fontsize':20})
plt.legend()
plt.show()

# %% [markdown]
# ### Post Vaccination breakthrough infection

# %%
data1={'name1':['Covaxin','Received 1st Dose','Received 2nd Dose'],
     'Doses1':[11000000,9356436,1737178],
     'positive1':[4963,4208,695]}
data2={'name2':['Covishield','Received 1st Dose','Received 2nd Dose'],
      'Doses2':[116000000,100302745,15732754],
      'positive2':[22159,17145,5014]}
df1=pd.DataFrame.from_dict(data1)
df2=pd.DataFrame.from_dict(data2)
df1
# Out:
#                name1    Doses1  positive1
# 0            Covaxin  11000000       4963
# 1  Received 1st Dose   9356436       4208
# 2  Received 2nd Dose   1737178        695

# %% [markdown]
# The plot below shows the post vaccination infection after 1st and 2nd dose of Covaxin and Covishield

# %%
plt.figure(figsize=(16,6))
ax1=plt.subplot(1,1,1)
ax1.bar(df1.name1,df1.Doses1,0.4,color='y',label='Vaccinated')
ax1.yaxis.grid(linestyle='-')
ax1.set_ylabel('vacciantion',fontdict={'fontweight':'bold','fontsize':14})
ax1.legend()
ax3=ax1.twinx()
ax3.plot(df1.name1,df1.positive1,'o-',color='b',label='+ve after vaccination',linewidth=3)
ax1.set_title("Post Vaccination Breakthrough Infection",fontdict={'fontweight':'bold','fontsize':20})
ax3.set_ylabel('+ve after vaccination',fontdict={'fontweight':'bold','fontsize':14})
ax3.legend()
plt.show()
plt.figure(figsize=(16,8))
ax2=plt.subplot(2,1,2)
ax2.bar(df2.name2,df2.Doses2,0.4,color='g',label='Vaccinated')
ax2.set_ylabel('vacciantion',fontdict={'fontweight':'bold','fontsize':14})
ax2.yaxis.grid(linestyle='-')
ax2.legend()
ax4=ax2.twinx()
ax4.plot(df2.name2,df2.positive2,'o-',color='r',label='+ve after vaccination',linewidth =3)

ax4.set_ylabel('+ve after vaccination',fontdict={'fontweight':'bold','fontsize':14})
ax4.legend()
plt.show()

# %% [markdown]
# ## Vaccination by age groups

# %%
#importing pandas
import pandas as pd

# %%
#loading csv file 
age=pd.read_csv("C:\\Users\\muska\\OneDrive\\Documents\\age.csv")

# %%
age
# Out:
#   Age group   Population
# 0     18-30    46,05,312
# 1     30-45    99,47,011
# 2     45-60  5,59,34,730
# 3   over 60  5,19,56,724

# %%
x=age['Age group']
x
# Out:
# 0      18-30
# 1      30-45
# 2      45-60
# 3    over 60
# Name: Age group, dtype: object

# %%
y=age['Population']
y
# Out:
# 0      46,05,312
# 1      99,47,011
# 2    5,59,34,730
# 3    5,19,56,724
# Name: Population, dtype: object

# %% [markdown]
# The plot below shows the number of people vaccinated from different age groups

# %%
plt.figure(figsize=(16,8))
plt.bar(x,y,color='y',label='Vaccinated')
plt.title('Vaccination by age groups',fontdict={'fontweight':'bold','fontsize':22})
plt.ylabel('no of people vaccinated',fontdict={'fontweight':'bold','fontsize':18})
plt.xlabel('Age groups',fontdict={'fontweight':'bold','fontsize':18})
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Correlation between vaccine administered, Active cases and Recovered

# %%
import pandas as pd

# %%
#loading file containing daywise vaccine administered
correlation=pd.read_csv('C:\\Users\\muska\\Downloads\\covid_vaccine_statewise.csv')
#changing datatype of column
correlation['Updated On']=pd.to_datetime(correlation['Updated On'],format= '%d/%m/%Y')
#getting data of india
corr=correlation.loc[(correlation['State']=='India') & (correlation['Updated On']<='16/4/2021')]
corr
# Out:
#    Updated On  State  Total Individuals Registered  Total Sessions Conducted  \
# 0  2021-01-16  India                     6943622.0                    3455.0
# 1  2021-01-17  India                     7119567.0                    8532.0
# 2  2021-01-18  India                     7150780.0                   13611.0
# 3  2021-01-19  India                     7423057.0                   17855.0
# 4  2021-01-20  India                     7555207.0                   25472.0
# ..        ...    ...                           ...                       ...
# 86 2021-04-12  India                    93559587.0                10664088.0
# 87 2021-04-13  India                    95823614.0                10046908.0
# 88 2021-04-14  India                    98703696.0                10786962.0
# 89 2021-04-15  India                   100853671.0                 9771019.0
# 90 2021-04-16  India                   102927296.0                 9780485.0
#
# ...

# %%
covaxin=corr['Total Covaxin Administered']
covaxin
# Out:
# 0          579.0
# 1          635.0
# 2         1299.0
# 3         3017.0
# 4         3946.0
#          ...
# 86     9117558.0
# 87     9279181.0
# 88     9632303.0
# 89     9850203.0
# 90    10178643.0
# Name: Total Covaxin Administered, Length: 91, dtype: float64

# %%
covishield=corr['Total CoviShield Administered']
covishield
# Out:
# 0         47697.0
# 1         57969.0
# 2         98150.0
# 3        192508.0
# 4        247334.0
#          ...
# 86     96852980.0
# 87     99319107.0
# 88    102280984.0
# 89    104747822.0
# 90    107126700.0
# Name: Total CoviShield Administered, Length: 91, dtype: float64

# %%
total=corr['Total Doses Administered']
total
# Out:
# 0         48276
# 1         58604
# 2         99449
# 3        195525
# 4        251280
#         ...
# 86    105970539
# 87    108598289
# 88    111913288
# 89    114598026
# 90    117305344
# Name: Total Doses Administered, Length: 91, dtype: int64

# %%
#loading file containing daywise cases in India
case =pd.read_csv('C:\\Users\\muska\\Downloads\\COVIDnew.csv')
# changing datatype of column
case['Date'] = pd.to_datetime(case['Date'], format='%d-%m-%Y')
# getting data of India only
covid=case.loc[(case['Region']=='India') & (case['Date']>='16-01-2021')]
covid
# Out:
#      S. No.       Date Region  Confirmed Cases  Active Cases  \
# 307     308 2021-01-16  India         10542841      211033.0
# 308     309 2021-01-17  India         10557985      208826.0
# 309     310 2021-01-18  India         10571773      208012.0
# 310     311 2021-01-19  India         10581837      200528.0
# 311     312 2021-01-20  India         10595660      197201.0
# ..      ...        ...    ...              ...           ...
# 393     394 2021-04-12  India         13527717     1201009.0
# 394     395 2021-04-13  India         13689453     1264698.0
# 395     396 2021-04-14  India         13873825     1365704.0
# 396     397 2021-04-15  India         14074564     1471877.0
# 397     398 2021-04-16  India         14291917     1569743.0
#
#      Cured/Discharged     Death
# 307        10179715.0  152093.0
# 308        10196885.0  152274.0
# 309        10211342.0  152419.0
# 310        10228753.0  152556.0
# 311        10245741.0  152718.0
# ..                ...       ...
# ...

# %%
active=covid['Active Cases']
active
# Out:
# 307     211033.0
# 308     208826.0
# 309     208012.0
# 310     200528.0
# 311     197201.0
#          ...
# 393    1201009.0
# 394    1264698.0
# 395    1365704.0
# 396    1471877.0
# 397    1569743.0
# Name: Active Cases, Length: 91, dtype: float64

# %%
recovered=covid['Cured/Discharged']
recovered
# Out:
# 307    10179715.0
# 308    10196885.0
# 309    10211342.0
# 310    10228753.0
# 311    10245741.0
#           ...
# 393    12156529.0
# 394    12253697.0
# 395    12336036.0
# 396    12429564.0
# 397    12547866.0
# Name: Cured/Discharged, Length: 91, dtype: float64

# %% [markdown]
# The below plot shows the correlations between Covaxin,Covishield and Total vaccine administered with active cases and recovered cases

# %%
plt.figure(figsize=(16,8))
plt.scatter(covaxin,active,label='Active cases',alpha=1,s=100)
plt.scatter(covaxin,recovered,label='Recovered',alpha=1,s=100)
plt.xlabel('covaxin administered',fontdict={'fontweight':'bold','fontsize':18})
plt.ylabel('no of cases',fontdict={'fontweight':'bold','fontsize':18})
plt.title("Correlation between covaxin administered with Active cases and recovered cases",fontdict={'fontweight':'bold','fontsize':22})
plt.legend()
plt.grid()
plt.show()
plt.figure(figsize=(16,8))
plt.scatter(covishield,active,label='Active cases',alpha=1,s=100)
plt.scatter(covishield,recovered,label='Recovered',alpha=1,s=100)
plt.xlabel('covishield administered',fontdict={'fontweight':'bold','fontsize':18})
plt.ylabel('no of cases',fontdict={'fontweight':'bold','fontsize':18})
plt.title("Correlation between covishield administered with Active cases and recovered cases",fontdict={'fontweight':'bold','fontsize':22})
plt.legend()
plt.grid()
plt.show()
plt.figure(figsize=(16,8))
plt.scatter(total,active,label='Active cases',alpha=1,s=100)
plt.scatter(total,recovered,label='Recovered',alpha=1,s=100)
plt.xlabel('total vaccine administered',fontdict={'fontweight':'bold','fontsize':18})
plt.ylabel('no of cases',fontdict={'fontweight':'bold','fontsize':18})
plt.title("Correlation between total vaccine administered with Active cases and recovered cases",fontdict={'fontweight':'bold','fontsize':22})
plt.legend()
plt.grid()
plt.show()
